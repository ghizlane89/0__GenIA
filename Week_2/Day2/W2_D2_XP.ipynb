# %%
#Exercice 1:

# 1. A company’s financial reports stored in an Excel file.
# → Structured Data


# 2. Photographs uploaded to a social media platform.
# → Unstructured Data


# 3. A collection of news articles on a website.
# → Unstructured Data


# 4. Inventory data in a relational database.
# → Structured Data


# 5. Recorded interviews from a market research study.
# → Unstructured Data

# %%
# 🌟 Exercise 2 – Transformation Exercise
# Goal: For each unstructured data source below, propose a way to convert it into structured data.
# Explain your reasoning for each case.

# 📘 1. A series of blog posts about travel experiences
# Type: Unstructured (text)
# Transformation:
# - Use NLP techniques (like Named Entity Recognition) to extract:
#   - Destination
#   - Dates
#   - Activities
#   - Budget
# - Result: a structured table like:
#   | Destination | Date       | Activity        | Budget (€) |
#   |-------------|------------|-----------------|------------|
#   | Japan       | 2023-08-10 | Hiking Mt. Fuji | 1200       |
# Reason: Enables analysis of common destinations, costs, and travel patterns.

# 🎧 2. Audio recordings of customer service calls
# Type: Unstructured (audio)
# Transformation:
# - Step 1: Use Speech-to-Text tools (e.g. Google Speech API, Whisper) to transcribe speech.
# - Step 2: Use NLP to extract key information like:
#   - Customer name
#   - Reason for the call
#   - Sentiment (positive/negative)
# - Result: a structured dataset like:
#   | Customer   | Reason           | Sentiment | Duration (min) |
#   |------------|------------------|-----------|----------------|
#   | John Smith | Request refund   | Negative  | 4.5            |
# Reason: Helps improve customer service quality and automate reporting.

# 📝 3. Handwritten notes from a brainstorming session
# Type: Unstructured (images of handwriting)
# Transformation:
# - Use OCR (Optical Character Recognition) tools like Tesseract or EasyOCR to digitize the text.
# - Organize notes by category or theme.
# - Result: a structured dataset like:
#   | Category    | Idea                                   |
#   |-------------|----------------------------------------|
#   | Marketing   | Launch TikTok campaign in Q3           |
#   | Product     | Add voice control to mobile app        |
# Reason: Makes brainstorming results easier to track and integrate into project planning.

# 🎥 4. A video tutorial on cooking
# Type: Unstructured (video)
# Transformation:
# - Step 1: Extract audio → Speech-to-Text transcription
# - Step 2: Use text parsing or NLP to identify:
#   - Ingredients
#   - Step-by-step instructions
#   - Time/duration per step
# - Result: a structured format like:
#   | Step | Instruction               | Time (min) |
#   |------|---------------------------|------------|
#   | 1    | Preheat oven to 180°C     | 5          |
#   | 2    | Mix flour and sugar       | 3          |
# Reason: Converts unstructured video into a searchable, usable recipe format.

# %%
#exercice 3

from google.colab import drive
drive.mount('/content/drive')


import pandas as pd

file_path = '/content/drive/My Drive/Datasets/train.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
# Mounted at /content/drive
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
#exercice 4



from google.colab import drive
drive.mount('/content/drive')


import pandas as pd

file_path = '/content/drive/My Drive/Datasets/Iris.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#exercice 5

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Create a simple DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Paris', 'London', 'New York']
}
df = pd.DataFrame(data)

# Export to Excel
excel_path = '/content/drive/My Drive/Datasets/people.xlsx'
df.to_excel(excel_path, index=False)

# Export to JSON
json_path = '/content/drive/My Drive/Datasets/people.json'
df.to_json(json_path, orient='records', indent=2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#exercice 6


from google.colab import drive
drive.mount('/content/drive')

import pandas as pd


file_path = '/content/drive/My Drive/Datasets/posts.json'
df = pd.read_json(file_path)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
