# %% [markdown]
# Daily Challenge

# %%
# Importation de la bibliothèque pandas pour la manipulation des données
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Lecture du fichier excel
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/W2/D5/US Superstore data.xls')
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# pour voir les colonnes et les types de données. En cas de présence d'object on devra encoder
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# pour voir max, min, moyenne
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
df.isnull().sum()
# There is no missing data as below :
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
#Convertir les colonnes de dates en datetime

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Calcul du Profit Margin en pourcentage
df['Profit Margin (%)'] = (df['Profit'] / df['Sales']) * 100

#Extraction de l’année et du mois de la commande
df['Order Year'] = df['Order Date'].dt.year
df['Order Month'] = df['Order Date'].dt.month
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
# Tendance des ventes mensuelles

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Agréger par mois
monthly_sales = df.groupby(pd.Grouper(key='Order Date', freq='ME'))['Sales'].sum()

# Tracer
plt.figure(figsize=(12,6))
plt.plot(monthly_sales.index, monthly_sales.values, marker='o')
plt.title('Tendance globale des ventes mensuelles')
plt.xlabel('Mois')
plt.ylabel('Ventes totales')
plt.grid(True)

# Ajouter un filtre interactif pour la catégorie
import ipywidgets as widgets
from IPython.display import display

categories = df['Category'].unique()
category_dropdown = widgets.Dropdown(options=categories, description='Catégorie:')

def plot_trend(cat):
    filtered_df = df[df['Category'] == cat]
    monthly = filtered_df.groupby(pd.Grouper(key='Order Date', freq='ME'))['Sales'].sum()
    plt.figure(figsize=(12,6))
    plt.plot(monthly.index, monthly.values, marker='o')
    plt.title(f'Tendance des ventes mensuelles pour {cat}')
    plt.xlabel('Mois')
    plt.ylabel('Ventes totales')
    plt.grid(True)
    plt.show()

widgets.interact(plot_trend, cat=category_dropdown)
# Out:
# interactive(children=(Dropdown(description='Catégorie:', options=('Furniture', 'Office Supplies', 'Technology'…
# <function __main__.plot_trend(cat)>

# %%
#Vente par état (top N)
import seaborn as sns

# Agréger par état
sales_by_state = df.groupby('State')['Sales'].sum().sort_values(ascending=False)

# Slider pour choisir top N
top_n_slider = widgets.IntSlider(min=1, max=50, step=1, value=10, description='Top N States:')

def plot_top_states(n):
    top_states = sales_by_state.head(n)
    plt.figure(figsize=(12,6))
    sns.barplot(x=top_states.values, y=top_states.index)
    plt.title(f'Top {n} États par ventes')
    plt.xlabel('Ventes')
    plt.ylabel('État')
    plt.show()

widgets.interact(plot_top_states, n=top_n_slider)
# Out:
# interactive(children=(IntSlider(value=10, description='Top N States:', max=50, min=1), Output()), _dom_classes…
# <function __main__.plot_top_states(n)>

# %%
#Produits les plus profitables
top_products = df.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top_products.values, y=top_products.index)
plt.title('Top 10 produits les plus profitables')
plt.xlabel('Profit total')
plt.ylabel('Produit')
for index, value in enumerate(top_products.values):
    plt.text(value, index, f'{value:.2f}', va='center')
plt.show()

# %%
# Analyse de l’impact du discount
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=df,
    x='Discount',
    y='Profit',
    hue='Category',
    alpha=0.9
)
# Ajout d’une ligne de tendance globale
sns.regplot(
    data=df,
    x='Discount', y='Profit',
    scatter=False, color='black'
)
plt.title('Relation entre Discount et Profit par Catégorie')
plt.xlabel('Remise (%)')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ### Comparatif entre Matplotlib et Seaborn
#
# | Critère                | Matplotlib                                              | Seaborn                                              |
# |------------------------|---------------------------------------------------------|-----------------------------------------------------|
# | Efficacité             | Plus long à écrire, mais très flexible pour des visualisations complexes | Rapide pour produire des graphiques esthétiques et lisibles |
# | Contrôle vs Conventions | Contrôle granulaire (axes, styles, annotations) | Prise en main rapide avec styles par défaut élégants |
# | Utilisation idéale     | Exploration approfondie, personnalisation avancée | Communication claire et visuelle pour rapports et présentations |
# | Politique future       | Pour exploration initiale ou visualisations complexes, privilégier Matplotlib | Pour visualisations finales, surtout pour communication, privilégier Seaborn |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row ID             9994 non-null   int64
#  1   Order ID           9994 non-null   object
#  2   Order Date         9994 non-null   datetime64[ns]
#  3   Ship Date          9994 non-null   datetime64[ns]
#  4   Ship Mode          9994 non-null   object
#  5   Customer ID        9994 non-null   object
#  6   Customer Name      9994 non-null   object
#  7   Segment            9994 non-null   object
#  8   Country            9994 non-null   object
#  9   City               9994 non-null   object
#  10  State              9994 non-null   object
#  11  Postal Code        9994 non-null   int64
#  12  Region             9994 non-null   object
#  13  Product ID         9994 non-null   object
#  14  Category           9994 non-null   object
# ...

# %% [markdown]
# La présence d'object dans la colonne Dtype suggère de procéder à de l'encoding

# %%
## A] Encodage Label (pour des variables avec peu de catégories, par exemple 'Region', 'Segment', 'Ship Mode')
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# Exemple pour 'Region'
le_region = LabelEncoder()
df['Region_encoded'] = le_region.fit_transform(df['Region'])

# Pour 'Segment'
le_segment = LabelEncoder()
df['Segment_encoded'] = le_segment.fit_transform(df['Segment'])

# Pour 'Ship Mode'
le_ship_mode = LabelEncoder()
df['Ship Mode_encoded'] = le_ship_mode.fit_transform(df['Ship Mode'])

## B] Encodage One-Hot (pour variables avec plusieurs catégories, par exemple 'Category', 'Sub-Category')
# Encodage One-Hot pour 'Category' et 'Sub-Category'
category_dummies = pd.get_dummies(df['Category'], prefix='Category')
sub_category_dummies = pd.get_dummies(df['Sub-Category'], prefix='SubCategory')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row ID             9994 non-null   int64
#  1   Order ID           9994 non-null   object
#  2   Order Date         9994 non-null   datetime64[ns]
#  3   Ship Date          9994 non-null   datetime64[ns]
#  4   Ship Mode          9994 non-null   object
#  5   Customer ID        9994 non-null   object
#  6   Customer Name      9994 non-null   object
#  7   Segment            9994 non-null   object
#  8   Country            9994 non-null   object
#  9   City               9994 non-null   object
#  10  State              9994 non-null   object
#  11  Postal Code        9994 non-null   int64
#  12  Region             9994 non-null   object
#  13  Product ID         9994 non-null   object
#  14  Category           9994 non-null   object
# ...

# %%
# Ajoute ces colonnes au DataFrame principal
df = pd.concat([df, category_dummies, sub_category_dummies], axis=1)

# Affichage graphique
sns.boxplot(x='Region_encoded', y='Sales', data=df)
plt.xticks(ticks=range(len(le_region.classes_)), labels=le_region.classes_)
plt.title('Distribution des ventes par région')
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Encodage de toutes les colonnes object en one-hot
df_encoded = pd.get_dummies(df, columns=df.select_dtypes(include='object').columns)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.select_dtypes(include='object').columns:
    df[col] = le.fit_transform(df[col])
df.info()
# Tous les object sont transformés en nombre comme ci-dessous, dataframe prêt à être exploité par l'IA :
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Row ID                    9994 non-null   int64
#  1   Order ID                  9994 non-null   int64
#  2   Order Date                9994 non-null   datetime64[ns]
#  3   Ship Date                 9994 non-null   datetime64[ns]
#  4   Ship Mode                 9994 non-null   int64
#  5   Customer ID               9994 non-null   int64
#  6   Customer Name             9994 non-null   int64
#  7   Segment                   9994 non-null   int64
#  8   Country                   9994 non-null   int64
#  9   City                      9994 non-null   int64
#  10  State                     9994 non-null   int64
#  11  Postal Code               9994 non-null   int64
#  12  Region                    9994 non-null   int64
# ...
