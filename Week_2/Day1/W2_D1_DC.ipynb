# %%
# Exercise 1: Introduction to Data Analysis (school version)

# 1. What is data analysis?
# Data analysis means studying information (like numbers or tables) to understand a situation better.
# We sort, organize, and look at the data to find useful ideas.
# This helps us know what is happening and make smarter choices.

# 2. Why is it important today?
# Today, we use phones, computers, and social media. All these things produce a lot of data.
# With data analysis, we can:
# - Understand what people need
# - Make good decisions
# - Improve services (like Netflix or transport)
# - Predict problems (like a system crash or a health issue)
# Without analysis, all this data is useless.

# 3. Three areas where it is used:
# - Health: to help doctors treat patients and follow diseases.
# - Business: to know what customers like and sell better.
# - Transport: to avoid traffic and plan better routes.



# Step 4 – Written Presentation
# Title: How UPS Uses Data Analysis to Improve Deliveries

# UPS (United Parcel Service) is one of the biggest delivery companies in the world.
# Every day, it handles millions of packages. To work better, UPS uses real-time data analysis.

# The company collects data from GPS, traffic, weather, and sensors in their vehicles.
# With this data, they calculate the best route for each truck.
# This system is called ORION (On-Road Integrated Optimization and Navigation).

# Thanks to ORION, UPS can:
# - Reduce fuel use
# - Save time and money
# - Avoid traffic and delays
# - Deliver more packages with fewer kilometers

# UPS says that if each driver drives just one kilometer less per day,
# the company can save millions of dollars every year.

# Why is it important?
# Without data analysis, drivers might take longer or less efficient routes.
# With data, UPS can make fast and smart decisions.
# This helps protect the environment, save money, and improve customer service.
# It is a clear example of how powerful data analysis can be in the real world.
