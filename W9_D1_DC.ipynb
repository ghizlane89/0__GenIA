# %% [markdown]
# <a href="https://colab.research.google.com/github/ghizlane89/0__GenIA/blob/Bootcamp/W9_D1_DC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""

🔹 Étape 1 :

Réécris le texte ci-dessous dans un ton amical et clair.
Utilise des puces pour structurer les informations.
Paraphrase le texte : n’utilise aucune citation directe.
Garde la réponse sous 75 mots.

Texte d’entrée :
"Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."

🔹 Étape 2 : Évaluer la sortie générée selon 6 critères :

1. Pertinence : respecte-t-elle le fond du message d'origine ?
2. Clarté : plus facile à comprendre pour un non-technicien ?
3. Structure : utilise-t-elle bien les puces ?
4. Ton : approprié pour une communication interne ?
5. Longueur : sous 75 mots ?
6. Exactitude : rien d’inventé ou de supprimé d’important ?


| **Critère**     | **Évaluation** | **Commentaire**                                                                                                         |
| --------------- | -------------- | ----------------------------------------------------------------------------------------------------------------------- |
| ✅ 1. Pertinence | ✔️ Oui         | L’exigence d’utiliser le VPN + l’interdiction des connexions non sécurisées/appareils non protégés sont bien présentes. |
| ✅ 2. Clarté     | ✔️ Oui         | Le langage est simple, accessible, sans jargon technique. Adapté à tous les niveaux.                                    |
| ✅ 3. Structure  | ✔️ Oui         | Informations bien structurées en 3 puces distinctes.                                                                    |
| ✅ 4. Ton        | ✔️ Oui         | Ton amical, direct, sans être autoritaire. Parfait pour une newsletter interne.                                         |
| ✅ 5. Longueur   | ✔️ Oui         | 47 mots → largement sous la limite de 75.                                                                               |
| ✅ 6. Exactitude | ✔️ Oui         | Rien d’ajouté ni retiré d’essentiel. Aucun détail critique n’est inventé.                                               |


🔹 Étape 3 : Mitigation des hallucinations

Paraphrase uniquement le contenu du texte fourni.
N’ajoute aucune nouvelle technologie, outil ou recommandation.
Garde un ton amical, utilise des puces et reste sous 75 mots.

Texte d’entrée :
"Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."


🔹 Étape 4 : Version pour un stagiaire débutant

Réécris le texte ci-dessous pour un stagiaire en début de parcours.
Utilise un langage simple avec des phrases courtes.
Fournis au maximum 4 bullet points.
Évite tout jargon technique, corporate ou juridique.
Garde un ton bienveillant, clair et informatif.

Texte d’entrée :
"Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."


🔹 Étape 5 : Variante citation

✅ Prompt « extraction de citation »

À partir du texte ci-dessous, extrais une seule citation directe qui reflète au mieux la règle de sécurité principale.
Ne paraphrase pas.
Garde seulement la phrase la plus représentative.

Texte d’entrée :
"Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."


==> Reflexion:

🟢 Quand citer est plus approprié :

Lors de communications officielles, par exemple :

Notes juridiques internes ou politiques RH

Mises à jour de conformité ou documents contractuels

Formations réglementaires où il faut montrer la formulation exacte

Cela permet d’appuyer un message en montrant que l’on respecte fidèlement le texte original.

🔴 Quand citer peut poser un risque :

Lorsque le texte est :

Trop formel, complexe ou technique pour un public non expert

Mal rédigé ou mal structuré, ce qui rend la citation confuse ou ambiguë

Déconnecté du contexte pratique et nécessite une explication ou simplification
