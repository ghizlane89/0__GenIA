# %% [markdown]
# <a href="https://colab.research.google.com/github/ghizlane89/0__GenIA/blob/Bootcamp/W8_D4_DC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Daily Challenge – Étude empirique sur les défis des développeurs d’applications LLM

## 1. Principales décisions méthodologiques
- **Sélection de la source de données** : uniquement les sous-forums du forum développeur OpenAI jugés pertinents (“API”, “Prompting”, “GPT Builders” et “ChatGPT”) ; exclusion des sections moins pertinentes (Community, Documentation, Announcements, Feedback).
- **Collecte à grande échelle** : 29 057 questions au total.
- **Échantillonnage représentatif** : sélection stratifiée de 2 364 posts pour codage manuel, couvrant un éventail varié de problèmes.
- **Procédure de codage ouvert** : deux annotateurs ont indépendamment identifié catégories et sous-catégories.
- **Construction itérative de la taxonomie** : catégories affinées par discussion et arbitrage, avec ajout de sous-catégories si nécessaire.
- **Arbitrage par un tiers** : un troisième annotateur a tranché les désaccords pour garantir la cohérence.

## 2. Validité et fiabilité de la procédure de codage
- **Forte concordance inter-annotateurs** : kappa de Cohen = 0,812, indiquant une excellente fiabilité.
- **Processus d’arbitrage** : désaccords résolus de manière systématique par un troisième expert.
- **Guide de codage structuré** : définitions précises des catégories pour standardiser l’interprétation.
- **Jeu de données représentatif** : reflète bien les préoccupations réelles des développeurs.

# %%
## 3. Taxonomie des défis (reconstituée)

Challenges for LLM Developers

Défis pour les développeurs LLM

├── 1. Conception de prompts & gestion du contexte
│ ├── Formulation du prompt
│ ├── Affinage itératif
│ ├── Injection de contexte (RAG, découpage)
│ └── Gestion des limites de tokens
├── 2. Coûts & quotas API
│ ├── Optimisation de l’utilisation des tokens
│ └── Gestion des limitations de débit
├── 3. Sécurité & confidentialité
│ ├── Protection des données personnelles (PII)
│ └── Conformité réglementaire (ex. RGPD)
├── 4. Performance & qualité des sorties
│ ├── Précision et pertinence
│ └── Stabilité / déterminisme des réponses
├── 5. Intégration & outils
│ ├── Intégration d’API / plugins
│ └── Streaming & journalisation
└── 6. Interprétation des sorties
├── Gestion de l’incertitude
└── Évaluation de la fiabilité

# %%
## 4. Défis dominants selon l’étude
- **Conception de prompts et limites de contexte** : difficulté à construire des prompts efficaces dans les limites de tokens.
- **Gestion des coûts** : coûts d’utilisation élevés et limitations d’API.
- **Préoccupations de sécurité** : manipulation de données sensibles et conformité légale.
- **Qualité variable des sorties** : hallucinations, manque de cohérence.
- **Complexité d’intégration** : connexion aux applications via API et plugins.

## 5. Implications pour la conception des plateformes/API LLM
- Intégrer **l’optimisation automatique des tokens et le suivi des coûts**.
- Fournir **l’anonymisation/masking des données sensibles** directement au niveau de l’API.
- Offrir **des outils de suivi de la qualité** (métriques de précision, détection d’hallucinations).
- Améliorer **les SDK d’intégration** (logs, streaming, débogage).
- Ajouter des **fonctionnalités d’explicabilité** pour comprendre les réponses.

## 6. Deux idées originales d’outils ou ressources communautaires
1. **Répertoire collaboratif de prompts**
   - Base de données communautaire de prompts, chacun accompagné de métriques de performance (tokens, coût, précision).
   - Étiquetage par usage, tests A/B intégrés, système de notation.

2. **API Wrapper “Safe & Cost-Aware”**
   - Bibliothèque intermédiaire qui :
     - Optimise automatiquement l’utilisation des tokens.
     - Anonymise les entrées sensibles.
     - Journalise la latence, le coût et la performance.
     - Adapte ses paramètres selon le mode (dev/test/prod).
