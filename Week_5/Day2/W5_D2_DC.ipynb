# %% [markdown]
# <a href="https://colab.research.google.com/github/ghizlane89/0__GenIA/blob/Bootcamp/W5_D2_DC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Understand Classification Types

# %%
1. Binary Classification (Classification binaire)
Définition : Le modèle prédit une seule classe parmi deux possibles.

Exemple : Est-ce qu’un email est spam ou non-spam ? (classes : 0 ou 1)

--------

2. Multi-class Classification (Classification multi-classes)
Définition : Le modèle choisit une classe parmi plusieurs (>2).

Exemple : Reconnaître un chiffre manuscrit de 0 à 9 (10 classes possibles).

------

3. Multi-label Classification
Définition : Le modèle peut attribuer plusieurs étiquettes simultanément à une même entrée.

Exemple : Une image peut contenir un chien 🐶, un chat 🐱 et une voiture 🚗 en même temps.

# %% [markdown]
# # 2. Set Up Your Python Environment and dataset

# %%
# 1. Import des bibliothèques
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.datasets import make_circles

# 2. Génération du dataset
samples = 1000
X, y = make_circles(n_samples=samples,
                    noise=0.03,
                    random_state=42)

print("X shape:", X.shape)
print("y shape:", y.shape)

# 3. Visualisation des données
plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.RdYlBu)
plt.title("make_circles dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# X shape: (1000, 2)
# y shape: (1000,)

# %% [markdown]
# # 3. Build a Basic Neural Network Model

# %%
# 1. Création du modèle
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid')  # 1 neurone en sortie, pour classe 0 ou 1
])

# 2. Compilation
model.compile(loss='binary_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# 3. Entraînement
history = model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4566 - loss: 0.7861
# Epoch 2/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4849 - loss: 0.7637
# Epoch 3/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4789 - loss: 0.7605
# Epoch 4/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5028 - loss: 0.7418
# Epoch 5/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5219 - loss: 0.7249
# Epoch 6/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5042 - loss: 0.7321
# Epoch 7/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5337 - loss: 0.7145
# Epoch 8/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5188 - loss: 0.7208
# Epoch 9/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5145 - loss: 0.7253
# Epoch 10/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5023 - loss: 0.7300
# Epoch 11/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4850 - loss: 0.7293
# Epoch 12/20
# ...

# %% [markdown]
# # 4. Improve the Model

# %%
# 1. Création du modèle amélioré
improved_model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu'),  # 1ère couche cachée : 10 neurones
    tf.keras.layers.Dense(10, activation='relu'),  # 2e couche cachée : 10 neurones
    tf.keras.layers.Dense(1, activation='sigmoid') # Sortie binaire
])

# 2. Compilation avec Adam
improved_model.compile(loss='binary_crossentropy',
                       optimizer='adam',  # optimiseur adaptatif
                       metrics=['accuracy'])

# 3. Entraînement
improved_history = improved_model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5014 - loss: 0.7466
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4877 - loss: 0.7212
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4714 - loss: 0.7078
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4825 - loss: 0.7004
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4568 - loss: 0.6988
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4110 - loss: 0.6986
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4302 - loss: 0.6953
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4898 - loss: 0.6935
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4851 - loss: 0.6948
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4972 - loss: 0.6902
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4967 - loss: 0.6881
# Epoch 12/100
# ...

# %% [markdown]
# # 5. Visualize the Decision Boundary

# %%
from sklearn.preprocessing import StandardScaler

# Standardisation pour ameliorer le modèle

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

improved_history = improved_model.fit(X_scaled, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5232 - loss: 4.2264
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 0.1030
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0416
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0454
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0436
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0414
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0403
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0379
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0386
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0389
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0403
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_decision_boundary(model, X, y):
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1

    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))

    grid = np.c_[xx.ravel(), yy.ravel()]
    preds = model.predict(grid)
    preds = preds.reshape(xx.shape)

    plt.contourf(xx, yy, preds, levels=[0, 0.5, 1], alpha=0.6, cmap="RdBu")
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap="bwr", edgecolors='k')
    plt.title("Decision Boundary")
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.show()

plot_decision_boundary(improved_model, X_scaled, y)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# # 6. Incorporate Activation Functions

# %%
# 1. Création du modèle avec ReLU (couches cachées) et Sigmoid (sortie)
activation_model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),   # 1ère couche cachée avec ReLU
    tf.keras.layers.Dense(32, activation='relu'),   # 2e couche cachée avec ReLU
    tf.keras.layers.Dense(1, activation='sigmoid')  # Couche de sortie avec Sigmoid
])

# 2. Compilation
activation_model.compile(loss='binary_crossentropy',
                         optimizer='adam',
                         metrics=['accuracy'])

# 3. Entraînement sur les données standardisées
activation_history = activation_model.fit(X_scaled, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4997 - loss: 0.6996
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4890 - loss: 0.6893
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5230 - loss: 0.6828
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5008 - loss: 0.6827
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5104 - loss: 0.6784
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5084 - loss: 0.6738
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5161 - loss: 0.6701
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5042 - loss: 0.6641
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5573 - loss: 0.6550
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6299 - loss: 0.6439
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8063 - loss: 0.6364
# Epoch 12/100
# ...

# %%
plot_decision_boundary(activation_model, X_scaled, y)

plt.plot(activation_history.history['accuracy'], label='Accuracy')
plt.plot(activation_history.history['loss'], label='Loss')
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.legend()
plt.title("Courbes d'apprentissage")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
#Commentaire

#Dans cette étape, nous avons exploré l’impact des fonctions d’activation ReLU et Sigmoid sur les performances d’un réseau de neurones. En intégrant ReLU dans les couches cachées et Sigmoid en sortie, le modèle a pu mieux capter la structure non linéaire des données générées par make_circles.

#Comparé aux modèles plus simples, cette architecture améliore significativement l’accuracy et produit une frontière de décision plus fluide et précise. Cela montre l'importance des fonctions d’activation dans la capacité d’un réseau à apprendre des motifs complexes.

# %% [markdown]
# # 7. Split Data into Training and Testing Sets

# %%
# Séparer les données

from sklearn.model_selection import train_test_split

# Si tu as déjà standardisé avec StandardScaler
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
# Recréer et entraîner le modèle sur X_train

model_split = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model_split.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])

history_split = model_split.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4912 - loss: 0.6960
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4791 - loss: 0.6897
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4932 - loss: 0.6855
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5076 - loss: 0.6839
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5010 - loss: 0.6805
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5095 - loss: 0.6770
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5169 - loss: 0.6714
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5495 - loss: 0.6683
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5966 - loss: 0.6611
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5938 - loss: 0.6626
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6054 - loss: 0.6605
# Epoch 12/100
# ...

# %%
#Évaluer sur le jeu de test

loss_test, accuracy_test = model_split.evaluate(X_test, y_test)
print(f"Test Loss: {loss_test:.4f}")
print(f"Test Accuracy: {accuracy_test:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0153
# Test Loss: 0.0160
# Test Accuracy: 1.0000

# %%
# Visualiser la frontière de décision sur l’ensemble complet

plot_decision_boundary(model_split, X_scaled, y)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
# accuracy sur le test est proche du train

# %% [markdown]
# # Étape 8 – Évaluation et Visualisation finale

# %%
# 1. Évaluation du modèle sur les données de test
loss_test, accuracy_test = model_split.evaluate(X_test, y_test)
print(f"Test Loss: {loss_test:.4f}")
print(f"Test Accuracy: {accuracy_test:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0153
# Test Loss: 0.0160
# Test Accuracy: 1.0000

# %%
# 2. Visualiser la frontière de décision sur le jeu d'entraînement

plot_decision_boundary(model_split, X_train, y_train)
plt.title("Frontière de décision - Données d'entraînement")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Text(0.5, 1.0, "Frontière de décision - Données d'entraînement")

# %%
# 3. Visualiser la frontière de décision sur le jeu de test

plot_decision_boundary(model_split, X_test, y_test)
plt.title("Frontière de décision - Données de test")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Text(0.5, 1.0, 'Frontière de décision - Données de test')

# %%
'''
Le modèle final, entraîné sur les données standardisées puis évalué sur le jeu de test (20 %), atteint une accuracy de 100 % et une loss très faible.

Cela signifie que :

Le modèle a parfaitement appris à séparer les deux classes, même sur des données jamais vues

La frontière de décision épouse très bien la forme des cercles imbriqués générés par make_circles, ce qui montre que l’architecture actuelle est adaptée à la complexité du problème

L’ajout de couches cachées avec ReLU, la standardisation des données, et l’usage de l’optimiseur Adam ont permis d’obtenir un modèle robuste, précis et bien généralisé

✅ Aucun signe de sous-apprentissage ou de sur-apprentissage pour le moment.

'''

# %% [markdown]
# # Étape 9 – Apply Regularization Techniques

# %%
# Regularization avec Dropout

from tensorflow.keras import layers, regularizers

model_dropout = tf.keras.Sequential([
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),  # 30% des neurones désactivés à chaque batch
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])

model_dropout.compile(loss='binary_crossentropy',
                      optimizer='adam',
                      metrics=['accuracy'])

history_dropout = model_dropout.fit(X_train, y_train, epochs=100)

# Évaluation
loss_d, acc_d = model_dropout.evaluate(X_test, y_test)
print(f"Test Accuracy avec Dropout : {acc_d:.4f}")
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4885 - loss: 0.6912
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5430 - loss: 0.6879
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5285 - loss: 0.6827
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5171 - loss: 0.6803
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5179 - loss: 0.6823
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5185 - loss: 0.6819
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5730 - loss: 0.6642
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5527 - loss: 0.6777
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5424 - loss: 0.6697
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5990 - loss: 0.6601
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6225 - loss: 0.6453
# Epoch 12/100
# ...

# %%
# Regularization avec L2 (poids pénalisés)

model_l2 = tf.keras.Sequential([
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dense(1, activation='sigmoid')
])

model_l2.compile(loss='binary_crossentropy',
                 optimizer='adam',
                 metrics=['accuracy'])

history_l2 = model_l2.fit(X_train, y_train, epochs=100)

# Évaluation
loss_l2, acc_l2 = model_l2.evaluate(X_test, y_test)
print(f"Test Accuracy avec L2 : {acc_l2:.4f}")
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4963 - loss: 1.3191
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5095 - loss: 1.1481
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5138 - loss: 1.0191
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5197 - loss: 0.9227
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5569 - loss: 0.8527
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6336 - loss: 0.8008
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7612 - loss: 0.7608
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7116 - loss: 0.7343
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6636 - loss: 0.7094
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8911 - loss: 0.6916
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8185 - loss: 0.6721
# Epoch 12/100
# ...

# %%
# Courbe de loss pendant l'entraînement

plt.figure(figsize=(12, 5))
plt.plot(history_split.history['loss'], label='Base model (no reg)')
plt.plot(history_dropout.history['loss'], label='Dropout model')
plt.plot(history_l2.history['loss'], label='L2 model')
plt.title('Loss pendant l\'entraînement')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 2. Courbe d’accuracy

plt.figure(figsize=(12, 5))
plt.plot(history_split.history['accuracy'], label='Base model (no reg)')
plt.plot(history_dropout.history['accuracy'], label='Dropout model')
plt.plot(history_l2.history['accuracy'], label='L2 model')
plt.title('Accuracy pendant l\'entraînement')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Résumé:

print(f"Accuracy base : {model_split.evaluate(X_test, y_test, verbose=0)[1]:.4f}")
print(f"Accuracy dropout : {model_dropout.evaluate(X_test, y_test, verbose=0)[1]:.4f}")
print(f"Accuracy L2 : {model_l2.evaluate(X_test, y_test, verbose=0)[1]:.4f}")
# Out:
# Accuracy base : 1.0000
# Accuracy dropout : 1.0000
# Accuracy L2 : 0.9950

# %%
#Dans ce projet, j’ai construit et amélioré un réseau de neurones pour classer des données non linéaires générées avec make_circles. J’ai expérimenté différentes architectures, les fonctions d’activation ReLU et Sigmoid, ainsi que des techniques de régularisation comme le Dropout et la régularisation L2.

#J’ai appris que de simples ajustements dans la structure du modèle ou les hyperparamètres peuvent considérablement influencer les performances.

#La visualisation de la frontière de décision a été un élément clé : elle m’a permis de vérifier si le modèle apprenait réellement la structure des données, au-delà des chiffres d’accuracy. De plus, tracer les courbes de loss et d’accuracy au fil des epochs m’a aidé à détecter les cas de sous-apprentissage ou de surapprentissage.

#Ce projet m’a permis de comprendre l’importance :

#De choisir une architecture adaptée à la complexité des données

#De visualiser les données et les prédictions du modèle

#De régler finement les hyperparamètres (taux d’apprentissage, nombre de neurones, régularisation)
#pour construire des modèles de classification plus robustes et performants.
