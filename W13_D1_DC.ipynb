# %% [markdown]
# <a href="https://colab.research.google.com/github/ghizlane89/0__GenIA/blob/Bootcamp/W13_D1_DC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Daily Challenge 19/08 — Votre Premier **Bot Intelligent** (Notebook)
# Ce notebook reprend la version **simplifiée** du défi et fournit un flow exécutable cellule par cellule.
#
# **Objectifs :**
# - Simuler MCP (handshake, découverte d’outils, notifications via `ctx.info()`).
# - Simuler un LLM qui résume des "articles".
# - Enregistrer un briefing dans un fichier texte.
#
# > Exécutez chaque cellule dans l’ordre. Les notifications apparaissent dans la sortie de cellule.

# %% [markdown]
# ## Cellule 1 — Imports

# %%
import os
import datetime
import time  # pour simuler des pauses

# %% [markdown]
# ## Cellule 2 — Classe `ContexteSimule` (notifications MCP)

# %%
# --- SIMULATION MCP : La Classe Contexte (pour les notifications de progrès) ---
class ContexteSimule:
    """Simule l'objet 'contexte' utilisé par les outils pour envoyer des notifications."""
    def info(self, message: str):
        print(f"   [NOTIFICATION] {message}")
        time.sleep(0.5)

# Test rapide (optionnel) :
# c = ContexteSimule(); c.info("Test de notification"); print("OK")

# %% [markdown]
# ## Cellule 3 — Outil 1 : `recherche_web_simulee(sujet)`

# %%
def recherche_web_simulee(sujet_de_recherche: str):
    print(f"   -> Outil 'recherche_web_simulee' appelé pour : '{sujet_de_recherche}'")
    articles_trouves = [
        {
            "titre": "Les secrets d'une bonne hydratation",
            "url": "http://fauxsite.com/hydratation",
            "texte": "Boire de l'eau est essentiel pour notre corps. Cela aide à réguler la température corporelle, à transporter les nutriments et à éliminer les toxines. Pensez à boire régulièrement tout au long de la journée."
        },
        {
            "titre": "L'importance du sommeil pour l'énergie",
            "url": "http://fauxsite.com/sommeil",
            "texte": "Un sommeil de qualité est crucial pour la récupération physique et mentale. Il influence directement notre humeur, notre concentration et notre système immunitaire. Établir une routine de sommeil peut grandement améliorer votre quotidien."
        },
        {
            "titre": "Bouger un peu, vivre mieux",
            "url": "http://fauxsite.com/activite-physique",
            "texte": "Même une activité physique légère améliore la circulation et l'humeur. Dix minutes de marche peuvent déjà réduire le stress. La régularité compte plus que l'intensité."
        }
    ]
    return {"resultats": articles_trouves}

# %% [markdown]
# ## Cellule 4 — Outil 2 : `resumer_avec_llm_simule(sujet, articles, ctx)`

# %%
def resumer_avec_llm_simule(sujet_du_briefing: str, liste_articles, ctx: ContexteSimule):
    ctx.info(f"Début du résumé pour le sujet : '{sujet_du_briefing}'")
    time.sleep(1)  # réflexion initiale

    resume_texte = f"Briefing Généré (LLM Simulé) sur : {sujet_du_briefing}\n\n"
    resume_texte += "Points Clés (Générés) :\n"

    sources_pour_llm = []
    for i, article in enumerate(liste_articles):
        ctx.info(f"Analyse de l'article {i+1} : {article.get('titre', 'Sans titre')}")
        texte = article.get("texte", "").strip()
        # Première phrase
        premiere_phrase = "(Aucune donnée disponible)."
        if texte:
            parts = [p.strip() for p in texte.split('. ') if p.strip()]
            if parts:
                premiere_phrase = parts[0]
                if not premiere_phrase.endswith('.'):
                    premiere_phrase += '.'
        resume_texte += f"- {premiere_phrase} [Source {i+1}]\n"
        sources_pour_llm.append(f"[Source {i+1}] {article.get('titre','Sans titre')} - {article.get('url','')}")
        time.sleep(0.3)

    resume_texte += "\nSources Utilisées :\n" + "\n".join(sources_pour_llm)
    ctx.info("Résumé terminé.")
    return {"briefing_complet": resume_texte}

# %% [markdown]
# ## Cellule 5 — Outil 3 : `enregistrer_fichier(nom, contenu)`

# %%
def enregistrer_fichier(nom_fichier: str, contenu_briefing: str):
    dossier_sortie = "briefings_generes"
    os.makedirs(dossier_sortie, exist_ok=True)
    chemin_complet = os.path.join(dossier_sortie, nom_fichier)
    try:
        with open(chemin_complet, "w", encoding="utf-8") as f:
            f.write(contenu_briefing)
        print(f"   -> Outil 'enregistrer_fichier' : Briefing enregistré dans '{chemin_complet}'")
        return {"chemin": chemin_complet}
    except Exception as e:
        print(f"Erreur lors de l'enregistrement du briefing : {e}")
        return {"chemin": None}

# %% [markdown]
# ## Cellule 6 — Outil 4 : `lister_outils_mcp_simule()` (Découverte d'outils)

# %%
def lister_outils_mcp_simule():
    print("   -> Outil 'lister_outils_mcp_simule' appelé.")
    outils_disponibles = [
        {"nom": "recherche_web_simulee", "description": "Recherche des articles sur un sujet donné."},
        {"nom": "resumer_avec_llm_simule", "description": "Génère un résumé avec un LLM simulé et envoie des notifications."},
        {"nom": "enregistrer_fichier", "description": "Sauvegarde un contenu dans un fichier texte."},
    ]
    return {"outils": outils_disponibles}

# %% [markdown]
# ## Cellule 7 — Orchestrateur (Handshake → Découverte → Workflow)

# %%
print('--- Démarrage du Client MCP Simulé ---')
print("\nSIMULATION MCP : Effectuation du 'handshake' (établissement de la connexion)...")
time.sleep(1)
print("SIMULATION MCP : Handshake terminé. La 'session' est établie.")

print("\nSIMULATION MCP : Demande des outils disponibles au 'serveur'...")
resultats_decouverte = lister_outils_mcp_simule()
print("SIMULATION MCP : Outils 'découverts' :")
for outil in resultats_decouverte['outils']:
    print(f" - {outil['nom']}: {outil['description']}")

# Sujet (modifiable ici)
sujet_utilisateur = "santé au quotidien"
print(f"\nLe bot va générer un briefing pour : '{sujet_utilisateur}'")

print("\n1. Appel de l'outil 'recherche_web_simulee'...")
result_recherche = recherche_web_simulee(sujet_utilisateur)
articles = result_recherche.get('resultats', [])
if not articles:
    print("   -> Aucun article simulé trouvé. Arrêt du processus.")
else:
    print(f"   -> {len(articles)} articles trouvés simulés.")

    print("\n2. Appel de l'outil 'resumer_avec_llm_simule' (regardez les NOTIFICATIONS !) ...")
    contexte_pour_llm = ContexteSimule()
    result_resume = resumer_avec_llm_simule(sujet_utilisateur, articles, contexte_pour_llm)
    contenu_briefing = result_resume.get('briefing_complet', "Erreur: Contenu non généré.")

    print("\n3. Appel de l'outil 'enregistrer_fichier'...")
    nom_fichier_propre = sujet_utilisateur.replace(' ', '_').replace("'", "").lower()
    nom_fichier_briefing = f"briefing_{nom_fichier_propre}_2025-08-19.txt"
    info_save = enregistrer_fichier(nom_fichier_briefing, contenu_briefing)
    print("\n--- Processus du Bot Intelligent Simulé Terminé ---")
    if info_save.get('chemin'):
        print(f"Votre briefing est prêt ! Ouvrez le fichier : '{info_save['chemin']}'")
    else:
        print("Une erreur est survenue lors de la création du briefing.")
# Out:
# --- Démarrage du Client MCP Simulé ---
#
# SIMULATION MCP : Effectuation du 'handshake' (établissement de la connexion)...
# SIMULATION MCP : Handshake terminé. La 'session' est établie.
#
# SIMULATION MCP : Demande des outils disponibles au 'serveur'...
#    -> Outil 'lister_outils_mcp_simule' appelé.
# SIMULATION MCP : Outils 'découverts' :
#  - recherche_web_simulee: Recherche des articles sur un sujet donné.
#  - resumer_avec_llm_simule: Génère un résumé avec un LLM simulé et envoie des notifications.
#  - enregistrer_fichier: Sauvegarde un contenu dans un fichier texte.
#
# Le bot va générer un briefing pour : 'santé au quotidien'
#
# 1. Appel de l'outil 'recherche_web_simulee'...
#    -> Outil 'recherche_web_simulee' appelé pour : 'santé au quotidien'
#    -> 3 articles trouvés simulés.
#
# 2. Appel de l'outil 'resumer_avec_llm_simule' (regardez les NOTIFICATIONS !) ...
#    [NOTIFICATION] Début du résumé pour le sujet : 'santé au quotidien'
#    [NOTIFICATION] Analyse de l'article 1 : Les secrets d'une bonne hydratation
#    [NOTIFICATION] Analyse de l'article 2 : L'importance du sommeil pour l'énergie
#    [NOTIFICATION] Analyse de l'article 3 : Bouger un peu, vivre mieux
#    [NOTIFICATION] Résumé terminé.
#
# 3. Appel de l'outil 'enregistrer_fichier'...
#    -> Outil 'enregistrer_fichier' : Briefing enregistré dans 'briefings_generes/briefing_santé_au_quotidien_2025-08-19.txt'
#
# --- Processus du Bot Intelligent Simulé Terminé ---
# Votre briefing est prêt ! Ouvrez le fichier : 'briefings_generes/briefing_santé_au_quotidien_2025-08-19.txt'
